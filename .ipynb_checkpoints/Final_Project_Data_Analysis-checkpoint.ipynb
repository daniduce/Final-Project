# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import geopandas as gp
# import pysal as ps
import seaborn as sb
import folium
import contextily
from sklearn.linear_model import LinearRegression
import pygeohash as gh
from polygeohasher import polygeohasher

from sqlalchemy import create_engine

import psycopg2

from config import db_password

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/final_project"

engine = create_engine(db_string)

conn = engine.connect()
import time

# %%
df = pd.read_csv(Path('./Resources/ibtracs.since1980.list.v04r00.csv'))
df = df.fillna("NA")
df.head()
# Out:
# C:\Users\jbate\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... WMO_AGENCY DS824_STAGE DS824_WIND DS824_PRES  \
# 0     TS -12.5000  172.500  ...                     TC         25
# 1     TS -12.1927  172.441  ...                     TC         25
# 2     TS -11.9144  172.412  ...                     TC         25
# 3     TS -11.6863  172.435  ...                     TC         25
# 4     TS -11.5000  172.500  ...                     TC         25
#
#   TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 0      -12.5      172.5            1              25               6
# 1   -12.2234    172.469            1                               6
# 2   -11.9575     172.45            1                               5
# 3   -11.7128    172.456            1                               4
# 4      -11.5      172.5            1                               4
#
#   STORM_DIR_degrees
# 0               351
# 1               351
# 2               358
# 3                12
# 4                22
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# SID                   object
# SEASON_Year            int64
# NUMBER                 int64
# BASIN                 object
# SUBBASIN              object
# NAME                  object
# ISO_TIME              object
# NATURE                object
# LAT                  float64
# LON                  float64
# WMO_WIND_KTS          object
# WMO_PRES              object
# WMO_AGENCY            object
# DS824_STAGE           object
# DS824_WIND            object
# DS824_PRES            object
# TD9636_LAT            object
# TD9636_LON            object
# TD9636_STAGE          object
# TD9636_WIND_KTS       object
# STORM_SPEED_KTS       object
# STORM_DIR_degrees     object
# dtype: object

# %%
#Drop unnamed storms
indexnames = df[df['NAME'] == 'NOT_NAMED'].index
df.drop(indexnames , inplace=True)
df.head()
# Out:
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... WMO_AGENCY DS824_STAGE DS824_WIND DS824_PRES  \
# 0     TS -12.5000  172.500  ...                     TC         25
# 1     TS -12.1927  172.441  ...                     TC         25
# 2     TS -11.9144  172.412  ...                     TC         25
# 3     TS -11.6863  172.435  ...                     TC         25
# 4     TS -11.5000  172.500  ...                     TC         25
#
#   TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 0      -12.5      172.5            1              25               6
# 1   -12.2234    172.469            1                               6
# 2   -11.9575     172.45            1                               5
# 3   -11.7128    172.456            1                               4
# 4      -11.5      172.5            1                               4
#
#   STORM_DIR_degrees
# 0               351
# 1               351
# 2               358
# 3                12
# 4                22
#
# [5 rows x 22 columns]

# %%
# Get geohash values
df['geohash']=df.apply(lambda x: gh.encode(x.LAT, x.LON, precision=5), axis=1)
df['geohash2']=df.apply(lambda x: gh.encode(x.LAT, x.LON, precision=2), axis=1)
df.head()
# Out:
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... DS824_WIND DS824_PRES TD9636_LAT TD9636_LON  \
# 0     TS -12.5000  172.500  ...         25                 -12.5      172.5
# 1     TS -12.1927  172.441  ...         25              -12.2234    172.469
# 2     TS -11.9144  172.412  ...         25              -11.9575     172.45
# 3     TS -11.6863  172.435  ...         25              -11.7128    172.456
# 4     TS -11.5000  172.500  ...         25                 -11.5      172.5
#
#   TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS STORM_DIR_degrees geohash  \
# 0            1              25               6               351   rvf8v
# 1            1                               6               351   rvfde
# 2            1                               5               358   rvfs5
# 3            1                               4                12   rvfte
# 4            1                               4                22   rvfwt
#
#   geohash2
# 0       rv
# 1       rv
# 2       rv
# 3       rv
# 4       rv
#
# [5 rows x 24 columns]

# %%
#add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df, s=0.05
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);
# Out:
# C:\Users\jbate\anaconda3\envs\PythonData\lib\site-packages\contextily\tile.py:583: RuntimeWarning: divide by zero encountered in log2
#   zoom_lon = np.ceil(np.log2(360 * 2.0 / lon_length))

# %%
#Filter df to North Atlantic(NA) basin
df_NA = df.loc[df['BASIN']=='NA']
df_NA.head()
# Out:
#                 SID  SEASON_Year  NUMBER BASIN SUBBASIN   NAME  \
# 3212  1980214N11330         1980      57    NA       NA  ALLEN
# 3213  1980214N11330         1980      57    NA       NA  ALLEN
# 3214  1980214N11330         1980      57    NA       NA  ALLEN
# 3215  1980214N11330         1980      57    NA       NA  ALLEN
# 3216  1980214N11330         1980      57    NA       NA  ALLEN
#
#              ISO_TIME NATURE      LAT      LON  ... DS824_WIND DS824_PRES  \
# 3212  7/31/1980 12:00     NR  11.0000 -30.0000  ...
# 3213  7/31/1980 15:00     NR  10.9509 -31.1101  ...
# 3214  7/31/1980 18:00     NR  10.9000 -32.2000  ...
# 3215  7/31/1980 21:00     NR  10.8496 -33.2574  ...
# 3216    8/1/1980 0:00     TS  10.8000 -34.3000  ...
#
#      TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 3212                                                                 22
# 3213                                                                 22
# 3214                                                                 21
# 3215                                                                 21
# 3216                                                                 21
#
#      STORM_DIR_degrees geohash geohash2
# 3212               267   e3fwt       e3
# 3213               267   e3cyk       e3
# 3214               267   e3cn5       e3
# 3215               267   e3bme       e3
# 3216               267   e1zt7       e1
#
# [5 rows x 24 columns]

# %%
#Map North Atlantic region and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_NA, s=0.05
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
#Filter df to storm Claudette
df_NA_CLAUDETTE = df_NA.loc[(df_NA.SID=='1985222N32280')]
df_NA_CLAUDETTE.head(5)
# Out:
#                  SID  SEASON_Year  NUMBER BASIN SUBBASIN       NAME  \
# 37082  1985222N32280         1985      65    NA       NA  CLAUDETTE
# 37083  1985222N32280         1985      65    NA       NA  CLAUDETTE
# 37084  1985222N32280         1985      65    NA       NA  CLAUDETTE
# 37085  1985222N32280         1985      65    NA       NA  CLAUDETTE
# 37086  1985222N32280         1985      65    NA       NA  CLAUDETTE
#
#              ISO_TIME NATURE      LAT      LON  ... DS824_WIND DS824_PRES  \
# 37082  8/9/1985 18:00     SS  31.5000 -80.5000  ...
# 37083  8/9/1985 21:00     SS  31.7505 -79.7631  ...
# 37084  8/10/1985 0:00     SS  32.0000 -79.0000  ...
# 37085  8/10/1985 3:00     SS  32.2501 -78.2124  ...
# 37086  8/10/1985 6:00     SS  32.5000 -77.5000  ...
#
#       TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 37082                                                                 14
# 37083                                                                 14
# 37084                                                                 14
# 37085                                                                 14
# 37086                                                                 12
#
#       STORM_DIR_degrees geohash geohash2
# 37082                68   djwg0       dj
# 37083                69   djxk8       dj
# 37084                69   djxy4       dj
# 37085                68   dm8rk       dm
# 37086                64   dmbbu       dm
#
# [5 rows x 24 columns]

# %%
#Map North Atlantic region and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_NA_CLAUDETTE, s=10
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
#Comment out after first run.

# #export storm data to csv
# df_NA.to_csv('NA_Storm_Data.csv',index=True)

# %%
df_NA.to_sql(schema='public', name='NA_Storms', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-c19af126ac2b> in <module>
# ----> 1 df_NA.to_sql(schema='public', name='NA_Storms', con=engine)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2787             chunksize=chunksize,
#    2788             dtype=dtype,
# -> 2789             method=method,
#    2790         )
#    2791
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     597         chunksize=chunksize,
#     598         dtype=dtype,
# --> 599         method=method,
#     600     )
#     601
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1390             dtype=dtype,
#    1391         )
# -> 1392         table.create()
#    1393
#    1394         from sqlalchemy import exc
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in create(self)
#     722         if self.exists():
#     723             if self.if_exists == "fail":
# --> 724                 raise ValueError(f"Table '{self.name}' already exists.")
#     725             elif self.if_exists == "replace":
#     726                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'NA_Storms' already exists.

# %%
#Import Us geojson
fname = "./Resources/gz_2010_us_040_00_500k.json"

df_US = gp.read_file(fname)



print(type(df_US))

df_US.head(5)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#         GEO_ID STATE           NAME LSAD  CENSUSAREA  \
# 0  0400000US23    23          Maine        30842.923
# 1  0400000US25    25  Massachusetts         7800.058
# 2  0400000US26    26       Michigan        56538.901
# 3  0400000US30    30        Montana       145545.801
# 4  0400000US32    32         Nevada       109781.180
#
#                                             geometry
# 0  MULTIPOLYGON (((-67.61976 44.51975, -67.61541 ...
# 1  MULTIPOLYGON (((-70.83204 41.60650, -70.82373 ...
# 2  MULTIPOLYGON (((-88.68443 48.11579, -88.67563 ...
# 3  POLYGON ((-104.05770 44.99743, -104.25015 44.9...
# 4  POLYGON ((-114.05060 37.00040, -114.04999 36.9...

# %%
df_FL = df_US.loc[df_US['NAME'] == 'Florida']

df_FL
# Out:
#          GEO_ID STATE     NAME LSAD  CENSUSAREA  \
# 27  0400000US12    12  Florida        53624.759
#
#                                              geometry
# 27  MULTIPOLYGON (((-85.15641 29.67963, -85.13740 ...

# %%
# REmoved due to long run time

# fname = "./Resources/gz_2010_us_040_00_500k.json"

# gdf = gp.read_file(fname)


# df_US = polygeohasher.create_geohash_list(gdf, 5,inner=False)

# %%
df_US

# %%
# df_FL = df_US.loc[df_US['NAME'] == 'Florida']

# df_FL

# %%
df_FL.dtypes
# Out:
# GEO_ID          object
# STATE           object
# NAME            object
# LSAD            object
# CENSUSAREA     float64
# geometry      geometry
# dtype: object

# %%
df_FL['geometry'].head()
# Out:
# 27    MULTIPOLYGON (((-85.15641 29.67963, -85.13740 ...
# Name: geometry, dtype: geometry

# %%
ax = df_FL.plot(
color='aquamarine', edgecolor='slategrey')
#gp.plot(ax=ax)

# %%
#export geojson to csv
df_FL.to_csv('df_FL_out.csv', columns=['geometry'],index=False)

# %%
df_FL = pd.read_csv(Path('./Resources/FL_LAT_LON.csv'))
df_FL.head()
# Out:
#    ID        LON        LAT
# 0   1 -85.156415  29.679628
# 1   2 -85.137397  29.684348
# 2   3 -85.134639  29.686569
# 3   4 -85.114268  29.688658
# 4   5 -85.093902  29.684838

# %%
#Map target area 
joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_FL, s=1
)

# %%
#Get Geohash data for FL boundaries

df_FL['geohash']=df_FL.apply(lambda x: gh.encode(x.LAT, x.LON, precision=5), axis=1)
df_FL
# Out:
#         ID        LON        LAT geohash
# 0        1 -85.156415  29.679628   dj72y
# 1        2 -85.137397  29.684348   dj72y
# 2        3 -85.134639  29.686569   dj72y
# 3        4 -85.114268  29.688658   dj72z
# 4        5 -85.093902  29.684838   dj72z
# ...    ...        ...        ...     ...
# 2223  2224 -84.573975  29.830572   dj7ce
# 2224  2225 -84.570877  29.822495   dj7ce
# 2225  2226 -84.579987  29.806856   dj7ce
# 2226  2227 -84.624840  29.788467   dj7c6
# 2227  2228 -84.670555  29.777298   dj7c3
#
# [2228 rows x 4 columns]

# %%
# #export df_FL to csv
df_FL.to_csv('FL_data.csv', mode='w')

# %%
 #Export df_FL to Postgres
df_FL.to_sql(name='target', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c761e37a5d4f> in <module>
#       1 #Export df_FL to Postgres
# ----> 2 df_FL.to_sql(name='target', con=engine)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2787             chunksize=chunksize,
#    2788             dtype=dtype,
# -> 2789             method=method,
#    2790         )
#    2791
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     597         chunksize=chunksize,
#     598         dtype=dtype,
# --> 599         method=method,
#     600     )
#     601
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1390             dtype=dtype,
#    1391         )
# -> 1392         table.create()
#    1393
#    1394         from sqlalchemy import exc
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in create(self)
#     722         if self.exists():
#     723             if self.if_exists == "fail":
# --> 724                 raise ValueError(f"Table '{self.name}' already exists.")
#     725             elif self.if_exists == "replace":
#     726                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'target' already exists.

# %%
#Do steps in Postgres before continuing.

# %%
df_fl_storms = pd.read_sql_table("fl_storms", engine)
df_fl_storms
# Out:
#      NUMBER    NAME  SEASON_Year NATURE      LAT      LON WMO_WIND_KTS  \
# 0        34     ANA         1991     DS  28.0000 -82.7000           20
# 1        34     ANA         1991     DS  28.0000 -82.7000           20
# 2        34     ANA         1991     DS  27.6425 -82.7375
# 3        34     ANA         1991     DS  27.6425 -82.7375
# 4        34     ANA         1991     DS  27.6425 -82.7375
# ..      ...     ...          ...    ...      ...      ...          ...
# 209      62  DENNIS         1981     TS  24.7300 -81.2999
# 210      62  DENNIS         1981     TS  24.7300 -81.2999
# 211      62  DENNIS         1981     TS  24.7300 -81.2999
# 212      62  DENNIS         1981     TS  24.7300 -81.2999
# 213      62  DENNIS         1981     TS  24.7300 -81.2999
#
#     WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees geohash
# 0       1012               7                 9   dhvpq
# 1       1012               7                 9   dhvpq
# 2                          7                 0   dhvjm
# 3                          7                 0   dhvjm
# 4                          7                 0   dhvjm
# ..       ...             ...               ...     ...
# 209                        4                 0   dhqht
# 210                        4                 0   dhqht
# 211                        4                 0   dhqht
# 212                        4                 0   dhqht
# 213                        4                 0   dhqht
#
# [214 rows x 11 columns]

# %%
df_na_storms_summary = pd.read_sql_table("na_storms_summary", engine)
df_na_storms_summary
# Out:
#      NUMBER            SID     NAME  SEASON_Year          ISO_TIME NATURE  \
# 0        57  1980214N11330    ALLEN         1980   7/31/1980 12:00     NR
# 1        62  1980227N13325   BONNIE         1980    8/14/1980 0:00     TS
# 2        63  1980234N36287  CHARLEY         1980   8/20/1980 12:00     SS
# 3        69  1980245N16322  GEORGES         1980    9/4/1980 18:00     NR
# 4        72  1980249N18336     EARL         1980    9/10/1980 0:00     TS
# ..      ...            ...      ...          ...               ...    ...
# 523      88  2020290N31305  EPSILON         2020   10/20/2020 0:00     TS
# 524      90  2020294N12280     ZETA         2020   10/20/2020 0:00     NR
# 525      94  2020303N12301      ETA         2020   10/29/2020 0:00     NR
# 526      97  2020313N28310    THETA         2020  11/12/2020 12:00     TS
# 527     101  2020318N16289     IOTA         2020  11/12/2020 12:00     DS
#
#       LAT   LON WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees  \
# 0    11.0 -30.0           25                       22               267
# 1    12.7 -35.5           25     1010              13               302
# 2    36.0 -73.0           25     1010              13               140
# 3    24.8 -64.8           20     1013              17               324
# 4    43.0 -39.0           65      994              31                41
# ..    ...   ...          ...      ...             ...               ...
# 523  25.2 -55.3                                     3               139
# 524  12.1 -80.0                                     4               345
# 525  12.0 -59.0                                     6               290
# 526  31.5 -29.4                                    12                89
# 527  15.5 -70.9                                    12               254
#
#     geohash geohash2  Strike_Target
# 0     e3fwt       e3            0.0
# 1     e4qb0       e4            1.0
# 2     dqkhf       dq            1.0
# 3     ds3vj       ds            0.0
# 4     epsk8       ep            1.0
# ..      ...      ...            ...
# 523   du2xm       du            0.0
# 524   d4phg       d4            0.0
# 525   ddnh3       dd            1.0
# 526   eme54       em            0.0
# 527   d6v84       d6            0.0
#
# [528 rows x 15 columns]

# %%
#Map Summary dataframe and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_na_storms_summary, s=5
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
def change_to_str(x):
    if x == 1:
        return 'yes'
    else:
        return 'no'

# %%
#Add Strike_Target_Name column based on Strike_Target value
df_na_storms_summary['Strike_Target_Name'] = df_na_storms_summary['Strike_Target'].map(change_to_str)
df_na_storms_summary
# Out:
#      NUMBER            SID     NAME  SEASON_Year          ISO_TIME NATURE  \
# 0        57  1980214N11330    ALLEN         1980   7/31/1980 12:00     NR
# 1        62  1980227N13325   BONNIE         1980    8/14/1980 0:00     TS
# 2        63  1980234N36287  CHARLEY         1980   8/20/1980 12:00     SS
# 3        69  1980245N16322  GEORGES         1980    9/4/1980 18:00     NR
# 4        72  1980249N18336     EARL         1980    9/10/1980 0:00     TS
# ..      ...            ...      ...          ...               ...    ...
# 523      88  2020290N31305  EPSILON         2020   10/20/2020 0:00     TS
# 524      90  2020294N12280     ZETA         2020   10/20/2020 0:00     NR
# 525      94  2020303N12301      ETA         2020   10/29/2020 0:00     NR
# 526      97  2020313N28310    THETA         2020  11/12/2020 12:00     TS
# 527     101  2020318N16289     IOTA         2020  11/12/2020 12:00     DS
#
#       LAT   LON WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees  \
# 0    11.0 -30.0           25                       22               267
# 1    12.7 -35.5           25     1010              13               302
# 2    36.0 -73.0           25     1010              13               140
# 3    24.8 -64.8           20     1013              17               324
# 4    43.0 -39.0           65      994              31                41
# ..    ...   ...          ...      ...             ...               ...
# 523  25.2 -55.3                                     3               139
# 524  12.1 -80.0                                     4               345
# 525  12.0 -59.0                                     6               290
# 526  31.5 -29.4                                    12                89
# 527  15.5 -70.9                                    12               254
#
#     geohash geohash2  Strike_Target Strike_Target_Name
# 0     e3fwt       e3            0.0                 no
# 1     e4qb0       e4            1.0                yes
# 2     dqkhf       dq            1.0                yes
# 3     ds3vj       ds            0.0                 no
# 4     epsk8       ep            1.0                yes
# ..      ...      ...            ...                ...
# 523   du2xm       du            0.0                 no
# 524   d4phg       d4            0.0                 no
# 525   ddnh3       dd            1.0                yes
# 526   eme54       em            0.0                 no
# 527   d6v84       d6            0.0                 no
#
# [528 rows x 16 columns]

# %%
# #export df_na_storms_summary to csv
df_na_storms_summary.to_csv('na_storms_summary.csv', mode='w')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-74-3e565832b7fc> in <module>
#       1 # #export df_na_storms_summary to csv
# ----> 2 df_na_storms_summary.to_csv('na_storms_summary.csv', mode='w')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# PermissionError: [Errno 13] Permission denied: 'na_storms_summary.csv'

# %%
df_na_storms_summary_endtime = pd.read_sql_table("na_storms_summary_endtime", engine)
df_na_storms_summary_endtime
# Out:
#      NUMBER            SID     NAME  SEASON_Year         ISO_TIME NATURE  \
# 0        57  1980214N11330    ALLEN         1980    8/9/1980 9:00     TS
# 1        62  1980227N13325   BONNIE         1980   8/19/1980 9:00     TS
# 2        63  1980234N36287  CHARLEY         1980   8/25/1980 9:00     TS
# 3        69  1980245N16322  GEORGES         1980    9/8/1980 9:00     TS
# 4        72  1980249N18336     EARL         1980    9/7/1980 9:00     TS
# ..      ...            ...      ...          ...              ...    ...
# 523      88  2020290N31305  EPSILON         2020  10/26/2020 0:00     TS
# 524      90  2020294N12280     ZETA         2020  10/29/2020 9:00     TS
# 525      94  2020303N12301      ETA         2020   11/9/2020 9:00     TS
# 526      97  2020313N28310    THETA         2020   11/9/2020 9:00     ET
# 527     101  2020318N16289     IOTA         2020  11/18/2020 9:00     TS
#
#          LAT      LON WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees  \
# 0    25.1226 -94.8378                                    11               280
# 1    44.1395 -39.2448                                    47                12
# 2    38.1313 -49.2303                                    34                88
# 3    44.2686 -53.1153                                    39                47
# 4    24.0250 -39.2798                                    20               335
# ..       ...      ...          ...      ...             ...               ...
# 523  47.3000 -41.3000                                    45                59
# 524  34.0534 -85.7673                                    41                52
# 525  25.0786 -82.1139                                    14               269
# 526  28.7071 -44.3802                                    10                78
# 527  13.8079 -88.3825                                    12               270
#
#     geohash geohash2  Strike_Target
# 0     9ukwc       9u            0.0
# 1     epu54       ep            1.0
# 2     dyubz       dy            1.0
# 3     dzf5z       dz            0.0
# 4     ehk0d       eh            1.0
# ..      ...      ...            ...
# 523   g06th       g0            0.0
# 524   dn518       dn            0.0
# 525   dhmwe       dh            1.0
# 526   ej07q       ej            0.0
# 527   d43ns       d4            0.0
#
# [528 rows x 15 columns]

# %%
#Add Strike_Target_Name column based on Strike_Target value
df_na_storms_summary_endtime['Strike_Target_Name'] = df_na_storms_summary_endtime['Strike_Target'].map(change_to_str)
df_na_storms_summary_endtime
# Out:
#      NUMBER            SID     NAME  SEASON_Year         ISO_TIME NATURE  \
# 0        57  1980214N11330    ALLEN         1980    8/9/1980 9:00     TS
# 1        62  1980227N13325   BONNIE         1980   8/19/1980 9:00     TS
# 2        63  1980234N36287  CHARLEY         1980   8/25/1980 9:00     TS
# 3        69  1980245N16322  GEORGES         1980    9/8/1980 9:00     TS
# 4        72  1980249N18336     EARL         1980    9/7/1980 9:00     TS
# ..      ...            ...      ...          ...              ...    ...
# 523      88  2020290N31305  EPSILON         2020  10/26/2020 0:00     TS
# 524      90  2020294N12280     ZETA         2020  10/29/2020 9:00     TS
# 525      94  2020303N12301      ETA         2020   11/9/2020 9:00     TS
# 526      97  2020313N28310    THETA         2020   11/9/2020 9:00     ET
# 527     101  2020318N16289     IOTA         2020  11/18/2020 9:00     TS
#
#          LAT      LON WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees  \
# 0    25.1226 -94.8378                                    11               280
# 1    44.1395 -39.2448                                    47                12
# 2    38.1313 -49.2303                                    34                88
# 3    44.2686 -53.1153                                    39                47
# 4    24.0250 -39.2798                                    20               335
# ..       ...      ...          ...      ...             ...               ...
# 523  47.3000 -41.3000                                    45                59
# 524  34.0534 -85.7673                                    41                52
# 525  25.0786 -82.1139                                    14               269
# 526  28.7071 -44.3802                                    10                78
# 527  13.8079 -88.3825                                    12               270
#
#     geohash geohash2  Strike_Target Strike_Target_Name
# 0     9ukwc       9u            0.0                 no
# 1     epu54       ep            1.0                yes
# 2     dyubz       dy            1.0                yes
# 3     dzf5z       dz            0.0                 no
# 4     ehk0d       eh            1.0                yes
# ..      ...      ...            ...                ...
# 523   g06th       g0            0.0                 no
# 524   dn518       dn            0.0                 no
# 525   dhmwe       dh            1.0                yes
# 526   ej07q       ej            0.0                 no
# 527   d43ns       d4            0.0                 no
#
# [528 rows x 16 columns]

# %%
#Map Summary endtime dataframe and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_na_storms_summary_endtime, s=5
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
# #export df_na_storms_summary_endtime to csv
df_na_storms_summary_endtime.to_csv('na_storms_summary_endtime.csv', mode='w')
