# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import geopandas as gp
# import pysal as ps
import seaborn as sb
import folium
import contextily
from sklearn.linear_model import LinearRegression
import pygeohash as gh
from polygeohasher import polygeohasher

from sqlalchemy import create_engine

import psycopg2

from config import db_password

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/final_project"

engine = create_engine(db_string)

conn = engine.connect()
import time

# %%
df = pd.read_csv(Path('./Resources/ibtracs.since1980.list.v04r00.csv'))
df = df.fillna("NA")
df.head()
# Out:
# C:\Users\jbate\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... WMO_AGENCY DS824_STAGE DS824_WIND DS824_PRES  \
# 0     TS -12.5000  172.500  ...                     TC         25
# 1     TS -12.1927  172.441  ...                     TC         25
# 2     TS -11.9144  172.412  ...                     TC         25
# 3     TS -11.6863  172.435  ...                     TC         25
# 4     TS -11.5000  172.500  ...                     TC         25
#
#   TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 0      -12.5      172.5            1              25               6
# 1   -12.2234    172.469            1                               6
# 2   -11.9575     172.45            1                               5
# 3   -11.7128    172.456            1                               4
# 4      -11.5      172.5            1                               4
#
#   STORM_DIR_degrees
# 0               351
# 1               351
# 2               358
# 3                12
# 4                22
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# SID                   object
# SEASON_Year            int64
# NUMBER                 int64
# BASIN                 object
# SUBBASIN              object
# NAME                  object
# ISO_TIME              object
# NATURE                object
# LAT                  float64
# LON                  float64
# WMO_WIND_KTS          object
# WMO_PRES              object
# WMO_AGENCY            object
# DS824_STAGE           object
# DS824_WIND            object
# DS824_PRES            object
# TD9636_LAT            object
# TD9636_LON            object
# TD9636_STAGE          object
# TD9636_WIND_KTS       object
# STORM_SPEED_KTS       object
# STORM_DIR_degrees     object
# dtype: object

# %%
#Drop unnamed storms
indexnames = df[df['NAME'] == 'NOT_NAMED'].index
df.drop(indexnames , inplace=True)
df.head()
# Out:
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... WMO_AGENCY DS824_STAGE DS824_WIND DS824_PRES  \
# 0     TS -12.5000  172.500  ...                     TC         25
# 1     TS -12.1927  172.441  ...                     TC         25
# 2     TS -11.9144  172.412  ...                     TC         25
# 3     TS -11.6863  172.435  ...                     TC         25
# 4     TS -11.5000  172.500  ...                     TC         25
#
#   TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 0      -12.5      172.5            1              25               6
# 1   -12.2234    172.469            1                               6
# 2   -11.9575     172.45            1                               5
# 3   -11.7128    172.456            1                               4
# 4      -11.5      172.5            1                               4
#
#   STORM_DIR_degrees
# 0               351
# 1               351
# 2               358
# 3                12
# 4                22
#
# [5 rows x 22 columns]

# %%
# Get geohash values
df['geohash']=df.apply(lambda x: gh.encode(x.LAT, x.LON, precision=5), axis=1)
df['geohash2']=df.apply(lambda x: gh.encode(x.LAT, x.LON, precision=2), axis=1)
df.head()
# Out:
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... DS824_WIND DS824_PRES TD9636_LAT TD9636_LON  \
# 0     TS -12.5000  172.500  ...         25                 -12.5      172.5
# 1     TS -12.1927  172.441  ...         25              -12.2234    172.469
# 2     TS -11.9144  172.412  ...         25              -11.9575     172.45
# 3     TS -11.6863  172.435  ...         25              -11.7128    172.456
# 4     TS -11.5000  172.500  ...         25                 -11.5      172.5
#
#   TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS STORM_DIR_degrees geohash  \
# 0            1              25               6               351   rvf8v
# 1            1                               6               351   rvfde
# 2            1                               5               358   rvfs5
# 3            1                               4                12   rvfte
# 4            1                               4                22   rvfwt
#
#   geohash2
# 0       rv
# 1       rv
# 2       rv
# 3       rv
# 4       rv
#
# [5 rows x 24 columns]

# %%
#add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df, s=0.05
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);
# Out:
# C:\Users\jbate\anaconda3\envs\PythonData\lib\site-packages\contextily\tile.py:583: RuntimeWarning: divide by zero encountered in log2
#   zoom_lon = np.ceil(np.log2(360 * 2.0 / lon_length))

# %%
#Filter df to North Atlantic(NA) basin
df_NA = df.loc[df['BASIN']=='NA']
df_NA.head()
# Out:
#                 SID  SEASON_Year  NUMBER BASIN SUBBASIN   NAME  \
# 3212  1980214N11330         1980      57    NA       NA  ALLEN
# 3213  1980214N11330         1980      57    NA       NA  ALLEN
# 3214  1980214N11330         1980      57    NA       NA  ALLEN
# 3215  1980214N11330         1980      57    NA       NA  ALLEN
# 3216  1980214N11330         1980      57    NA       NA  ALLEN
#
#              ISO_TIME NATURE      LAT      LON  ... DS824_WIND DS824_PRES  \
# 3212  7/31/1980 12:00     NR  11.0000 -30.0000  ...
# 3213  7/31/1980 15:00     NR  10.9509 -31.1101  ...
# 3214  7/31/1980 18:00     NR  10.9000 -32.2000  ...
# 3215  7/31/1980 21:00     NR  10.8496 -33.2574  ...
# 3216    8/1/1980 0:00     TS  10.8000 -34.3000  ...
#
#      TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 3212                                                                 22
# 3213                                                                 22
# 3214                                                                 21
# 3215                                                                 21
# 3216                                                                 21
#
#      STORM_DIR_degrees geohash geohash2
# 3212               267   e3fwt       e3
# 3213               267   e3cyk       e3
# 3214               267   e3cn5       e3
# 3215               267   e3bme       e3
# 3216               267   e1zt7       e1
#
# [5 rows x 24 columns]

# %%
#Map North Atlantic region and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_NA, s=0.05
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
# #export storm data to csv
df_NA.to_csv('NA_Storm_Data.csv',index=True, mode='w')

# %%
#Comment out after DB creation
#Export df_NA to Postgres

#df_NA.to_sql(schema='public', name='NA_Storms', con=engine)

# %%
df_FL = pd.read_csv(Path('./Resources/FL_LAT_LON.csv'))
df_FL.head()
# Out:
#    ID        LON        LAT
# 0   1 -85.156415  29.679628
# 1   2 -85.137397  29.684348
# 2   3 -85.134639  29.686569
# 3   4 -85.114268  29.688658
# 4   5 -85.093902  29.684838

# %%
#Map target area 
joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_FL, s=1
)

# %%
#Get Geohash data for FL boundaries

df_FL['geohash']=df_FL.apply(lambda x: gh.encode(x.LAT, x.LON, precision=5), axis=1)
df_FL
# Out:
#         ID        LON        LAT geohash
# 0        1 -85.156415  29.679628   dj72y
# 1        2 -85.137397  29.684348   dj72y
# 2        3 -85.134639  29.686569   dj72y
# 3        4 -85.114268  29.688658   dj72z
# 4        5 -85.093902  29.684838   dj72z
# ...    ...        ...        ...     ...
# 2223  2224 -84.573975  29.830572   dj7ce
# 2224  2225 -84.570877  29.822495   dj7ce
# 2225  2226 -84.579987  29.806856   dj7ce
# 2226  2227 -84.624840  29.788467   dj7c6
# 2227  2228 -84.670555  29.777298   dj7c3
#
# [2228 rows x 4 columns]

# %%
# #export df_FL to csv
df_FL.to_csv('FL_data.csv', mode='w')

# %%
#Comment out after DB creation
#Export df_FL to Postgres

#df_FL.to_sql(name='target', con=engine)

# %%
#Do steps in Postgres before continuing.

# %%
df_fl_storms = pd.read_sql_table("fl_storms", engine)
df_fl_storms
# Out:
#      NUMBER            SID    NAME  SEASON_Year NATURE      LAT      LON  \
# 0        34  1991181N26282     ANA         1991     DS  28.0000 -82.7000
# 1        34  1991181N26282     ANA         1991     DS  28.0000 -82.7000
# 2        38  1995212N22287    ERIN         1995     TS  28.4239 -82.6781
# 3        38  1995212N22287    ERIN         1995     TS  28.4239 -82.6781
# 4        24  2013157N25273  ANDREA         2013     TS  29.5000 -83.4000
# ..      ...            ...     ...          ...    ...      ...      ...
# 209      62  1981219N11334  DENNIS         1981     TS  24.7300 -81.2999
# 210      62  1981219N11334  DENNIS         1981     TS  24.7300 -81.2999
# 211      62  1981219N11334  DENNIS         1981     TS  24.7300 -81.2999
# 212      62  1981219N11334  DENNIS         1981     TS  24.7300 -81.2999
# 213      62  1981219N11334  DENNIS         1981     TS  24.7300 -81.2999
#
#     WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees geohash
# 0             20     1012               7                 9   dhvpq
# 1             20     1012               7                 9   dhvpq
# 2                                      14               287   djj1w
# 3                                      14               287   djj1w
# 4             50      992              13                47   djhxy
# ..           ...      ...             ...               ...     ...
# 209                                     4                 0   dhqht
# 210                                     4                 0   dhqht
# 211                                     4                 0   dhqht
# 212                                     4                 0   dhqht
# 213                                     4                 0   dhqht
#
# [214 rows x 12 columns]

# %%
#Map Florida Storms and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_fl_storms, s=10
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
df_na_storms_summary = pd.read_sql_table("na_storms_summary", engine)
df_na_storms_summary
# Out:
#      NUMBER            SID     NAME  SEASON_Year          ISO_TIME NATURE  \
# 0        57  1980214N11330    ALLEN         1980   7/31/1980 12:00     NR
# 1        62  1980227N13325   BONNIE         1980    8/14/1980 0:00     TS
# 2        63  1980234N36287  CHARLEY         1980   8/20/1980 12:00     SS
# 3        69  1980245N16322  GEORGES         1980    9/4/1980 18:00     NR
# 4        72  1980249N18336     EARL         1980    9/10/1980 0:00     TS
# ..      ...            ...      ...          ...               ...    ...
# 523      88  2020290N31305  EPSILON         2020   10/16/2020 0:00     DS
# 524      90  2020294N12280     ZETA         2020   10/29/2020 0:00     TS
# 525      94  2020303N12301      ETA         2020  11/12/2020 12:00     TS
# 526      97  2020313N28310    THETA         2020  11/12/2020 12:00     TS
# 527     101  2020318N16289     IOTA         2020  11/12/2020 12:00     DS
#
#       LAT   LON WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees  \
# 0    11.0 -30.0           25                       22               267
# 1    12.7 -35.5           25     1010              13               302
# 2    36.0 -73.0           25     1010              13               140
# 3    24.8 -64.8           20     1013              17               324
# 4    43.0 -39.0           65      994              31                41
# ..    ...   ...          ...      ...             ...               ...
# 523  31.2 -55.4                                     6               103
# 524  30.2 -89.9                                    28                31
# 525  29.8 -82.4                                    17                33
# 526  31.5 -29.4                                    12                89
# 527  15.5 -70.9                                    12               254
#
#     geohash geohash2  Strike_Target
# 0     e3fwt       e3            0.0
# 1     e4qb0       e4            0.0
# 2     dqkhf       dq            0.0
# 3     ds3vj       ds            0.0
# 4     epsk8       ep            0.0
# ..      ...      ...            ...
# 523   dv897       dv            0.0
# 524   dj25f       dj            0.0
# 525   djm3s       dj            1.0
# 526   eme54       em            0.0
# 527   d6v84       d6            0.0
#
# [528 rows x 15 columns]

# %%
#Map Summary dataframe and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_na_storms_summary, s=5
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
def change_to_str(x):
    if x == 1:
        return 'yes'
    else:
        return 'no'

# %%
#Add Strike_Target_Name column based on Strike_Target value
df_na_storms_summary['Strike_Target_Name'] = df_na_storms_summary['Strike_Target'].map(change_to_str)
df_na_storms_summary
len (df_na_storms_summary.index)
# Out:
# 528

# %%
# #export df_na_storms_summary to csv
df_na_storms_summary.to_csv('na_storms_summary.csv', mode='w')

# %%
df_na_storms_summary_endtime = pd.read_sql_table("na_storms_summary_endtime", engine)
df_na_storms_summary_endtime
# Out:
#      NUMBER            SID     NAME  SEASON_Year         ISO_TIME NATURE  \
# 0        57  1980214N11330    ALLEN         1980    8/9/1980 9:00     TS
# 1        62  1980227N13325   BONNIE         1980   8/19/1980 9:00     TS
# 2        63  1980234N36287  CHARLEY         1980   8/25/1980 9:00     TS
# 3        69  1980245N16322  GEORGES         1980    9/7/1980 9:00     TS
# 4        72  1980249N18336     EARL         1980    9/8/1980 9:00     TS
# ..      ...            ...      ...          ...              ...    ...
# 523      88  2020290N31305  EPSILON         2020  10/26/2020 0:00     TS
# 524      90  2020294N12280     ZETA         2020  10/26/2020 0:00     TS
# 525      94  2020303N12301      ETA         2020  10/29/2020 9:00     NR
# 526      97  2020313N28310    THETA         2020   11/9/2020 9:00     ET
# 527     101  2020318N16289     IOTA         2020  11/18/2020 9:00     TS
#
#          LAT      LON WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees  \
# 0    25.1226 -94.8378                                    11               280
# 1    44.1395 -39.2448                                    47                12
# 2    38.1313 -49.2303                                    34                88
# 3    36.6144 -64.8134                                    23                52
# 4    31.2073 -43.0525                                    18               332
# ..       ...      ...          ...      ...             ...               ...
# 523  47.3000 -41.3000                                    45                59
# 524  18.0667 -83.7000                                     2               342
# 525  12.3000 -59.9425                                     7               286
# 526  28.7071 -44.3802                                    10                78
# 527  13.8079 -88.3825                                    12               270
#
#     geohash geohash2  Strike_Target
# 0     9ukwc       9u            0.0
# 1     epu54       ep            0.0
# 2     dyubz       dy            0.0
# 3     dw9bm       dw            0.0
# 4     ej93s       ej            0.0
# ..      ...      ...            ...
# 523   g06th       g0            0.0
# 524   d5hqz       d5            0.0
# 525   ddjmg       dd            1.0
# 526   ej07q       ej            0.0
# 527   d43ns       d4            0.0
#
# [528 rows x 15 columns]

# %%
#Add Strike_Target_Name column based on Strike_Target value
df_na_storms_summary_endtime['Strike_Target_Name'] = df_na_storms_summary_endtime['Strike_Target'].map(change_to_str)
df_na_storms_summary_endtime
# Out:
#      NUMBER            SID     NAME  SEASON_Year         ISO_TIME NATURE  \
# 0        57  1980214N11330    ALLEN         1980    8/9/1980 9:00     TS
# 1        62  1980227N13325   BONNIE         1980   8/19/1980 9:00     TS
# 2        63  1980234N36287  CHARLEY         1980   8/25/1980 9:00     TS
# 3        69  1980245N16322  GEORGES         1980    9/7/1980 9:00     TS
# 4        72  1980249N18336     EARL         1980    9/8/1980 9:00     TS
# ..      ...            ...      ...          ...              ...    ...
# 523      88  2020290N31305  EPSILON         2020  10/26/2020 0:00     TS
# 524      90  2020294N12280     ZETA         2020  10/26/2020 0:00     TS
# 525      94  2020303N12301      ETA         2020  10/29/2020 9:00     NR
# 526      97  2020313N28310    THETA         2020   11/9/2020 9:00     ET
# 527     101  2020318N16289     IOTA         2020  11/18/2020 9:00     TS
#
#          LAT      LON WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees  \
# 0    25.1226 -94.8378                                    11               280
# 1    44.1395 -39.2448                                    47                12
# 2    38.1313 -49.2303                                    34                88
# 3    36.6144 -64.8134                                    23                52
# 4    31.2073 -43.0525                                    18               332
# ..       ...      ...          ...      ...             ...               ...
# 523  47.3000 -41.3000                                    45                59
# 524  18.0667 -83.7000                                     2               342
# 525  12.3000 -59.9425                                     7               286
# 526  28.7071 -44.3802                                    10                78
# 527  13.8079 -88.3825                                    12               270
#
#     geohash geohash2  Strike_Target Strike_Target_Name
# 0     9ukwc       9u            0.0                 no
# 1     epu54       ep            0.0                 no
# 2     dyubz       dy            0.0                 no
# 3     dw9bm       dw            0.0                 no
# 4     ej93s       ej            0.0                 no
# ..      ...      ...            ...                ...
# 523   g06th       g0            0.0                 no
# 524   d5hqz       d5            0.0                 no
# 525   ddjmg       dd            1.0                yes
# 526   ej07q       ej            0.0                 no
# 527   d43ns       d4            0.0                 no
#
# [528 rows x 16 columns]

# %%
df_na_storms_summary_endtime = df_na_storms_summary_endtime.rename({'ISO_TIME': 'ISO_TIME_END', 'LAT': 'LAT_END', 'LON': 'LON_END', 'NATURE': 'NATURE_END', 'geohash': 'geohash_end'}, axis=1)
df_na_storms_summary_endtime
len (df_na_storms_summary_endtime.index)
# Out:
# 528

# %%
#Map Summary endtime dataframe and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON_END', y='LAT_END', data=df_na_storms_summary_endtime, s=5
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
#export df_na_storms_summary_endtime to csv
df_na_storms_summary_endtime.to_csv('na_storms_summary_endtime.csv', mode='w')

# %%
#Combine storm summary df's

data= [df_na_storms_summary[{'NUMBER', 'SID', 'NAME', 'SEASON_Year', 'ISO_TIME', 'NATURE', 'LAT', 'LON', 'WMO_WIND_KTS', 'WMO_PRES', 'STORM_SPEED_KTS', 'STORM_DIR_degrees', 'geohash', 'geohash2', 'Strike_Target', 'Strike_Target_Name'}], df_na_storms_summary_endtime[{'ISO_TIME_END', 'NATURE_END', 'LAT_END', 'LON_END', 'geohash_end'}]]

df_combined = pd.concat(data, axis=1)
df_combined
# Out:
#     NATURE   LON  Strike_Target   LAT          ISO_TIME geohash     NAME  \
# 0       NR -30.0            0.0  11.0   7/31/1980 12:00   e3fwt    ALLEN
# 1       TS -35.5            0.0  12.7    8/14/1980 0:00   e4qb0   BONNIE
# 2       SS -73.0            0.0  36.0   8/20/1980 12:00   dqkhf  CHARLEY
# 3       NR -64.8            0.0  24.8    9/4/1980 18:00   ds3vj  GEORGES
# 4       TS -39.0            0.0  43.0    9/10/1980 0:00   epsk8     EARL
# ..     ...   ...            ...   ...               ...     ...      ...
# 523     DS -55.4            0.0  31.2   10/16/2020 0:00   dv897  EPSILON
# 524     TS -89.9            0.0  30.2   10/29/2020 0:00   dj25f     ZETA
# 525     TS -82.4            1.0  29.8  11/12/2020 12:00   djm3s      ETA
# 526     TS -29.4            0.0  31.5  11/12/2020 12:00   eme54    THETA
# 527     DS -70.9            0.0  15.5  11/12/2020 12:00   d6v84     IOTA
#
#     WMO_WIND_KTS  NUMBER  SEASON_Year  ... Strike_Target_Name  \
# 0             25      57         1980  ...                 no
# 1             25      62         1980  ...                 no
# 2             25      63         1980  ...                 no
# 3             20      69         1980  ...                 no
# 4             65      72         1980  ...                 no
# ..           ...     ...          ...  ...                ...
# 523                   88         2020  ...                 no
# 524                   90         2020  ...                 no
# 525                   94         2020  ...                yes
# 526                   97         2020  ...                 no
# 527                  101         2020  ...                 no
#
#     STORM_DIR_degrees            SID geohash2 STORM_SPEED_KTS  LON_END  \
# 0                 267  1980214N11330       e3              22 -94.8378
# 1                 302  1980227N13325       e4              13 -39.2448
# 2                 140  1980234N36287       dq              13 -49.2303
# 3                 324  1980245N16322       ds              17 -64.8134
# 4                  41  1980249N18336       ep              31 -43.0525
# ..                ...            ...      ...             ...      ...
# 523               103  2020290N31305       dv               6 -41.3000
# 524                31  2020294N12280       dj              28 -83.7000
# 525                33  2020303N12301       dj              17 -59.9425
# 526                89  2020313N28310       em              12 -44.3802
# 527               254  2020318N16289       d6              12 -88.3825
#
#      LAT_END     ISO_TIME_END geohash_end NATURE_END
# 0    25.1226    8/9/1980 9:00       9ukwc         TS
# 1    44.1395   8/19/1980 9:00       epu54         TS
# 2    38.1313   8/25/1980 9:00       dyubz         TS
# 3    36.6144    9/7/1980 9:00       dw9bm         TS
# 4    31.2073    9/8/1980 9:00       ej93s         TS
# ..       ...              ...         ...        ...
# 523  47.3000  10/26/2020 0:00       g06th         TS
# 524  18.0667  10/26/2020 0:00       d5hqz         TS
# 525  12.3000  10/29/2020 9:00       ddjmg         NR
# 526  28.7071   11/9/2020 9:00       ej07q         ET
# 527  13.8079  11/18/2020 9:00       d43ns         TS
#
# [528 rows x 21 columns]

# %%
#export df_na_storms_summary_endtime to csv
df_combined.to_csv('na_storms_combined.csv', mode='w')
