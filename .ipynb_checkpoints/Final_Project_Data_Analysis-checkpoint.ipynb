# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import geopandas as gp
# import pysal as ps
import seaborn as sb
import folium
import contextily
from sklearn.linear_model import LinearRegression
import pygeohash as gh
from polygeohasher import polygeohasher

from sqlalchemy import create_engine

import psycopg2

from config import db_password

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/final_project"

engine = create_engine(db_string)

conn = engine.connect()
import time

# %%
df = pd.read_csv(Path('./Resources/ibtracs.since1980.list.v04r00.csv'))
df = df.fillna("NA")
df.head()
# Out:
# C:\Users\jbate\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... WMO_AGENCY DS824_STAGE DS824_WIND DS824_PRES  \
# 0     TS -12.5000  172.500  ...                     TC         25
# 1     TS -12.1927  172.441  ...                     TC         25
# 2     TS -11.9144  172.412  ...                     TC         25
# 3     TS -11.6863  172.435  ...                     TC         25
# 4     TS -11.5000  172.500  ...                     TC         25
#
#   TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 0      -12.5      172.5            1              25               6
# 1   -12.2234    172.469            1                               6
# 2   -11.9575     172.45            1                               5
# 3   -11.7128    172.456            1                               4
# 4      -11.5      172.5            1                               4
#
#   STORM_DIR_degrees
# 0               351
# 1               351
# 2               358
# 3                12
# 4                22
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# SID                   object
# SEASON_Year            int64
# NUMBER                 int64
# BASIN                 object
# SUBBASIN              object
# NAME                  object
# ISO_TIME              object
# NATURE                object
# LAT                  float64
# LON                  float64
# WMO_WIND_KTS          object
# WMO_PRES              object
# WMO_AGENCY            object
# DS824_STAGE           object
# DS824_WIND            object
# DS824_PRES            object
# TD9636_LAT            object
# TD9636_LON            object
# TD9636_STAGE          object
# TD9636_WIND_KTS       object
# STORM_SPEED_KTS       object
# STORM_DIR_degrees     object
# dtype: object

# %%
#Drop unnamed storms
indexnames = df[df['NAME'] == 'NOT_NAMED'].index
df.drop(indexnames , inplace=True)
df.head()
# Out:
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... WMO_AGENCY DS824_STAGE DS824_WIND DS824_PRES  \
# 0     TS -12.5000  172.500  ...                     TC         25
# 1     TS -12.1927  172.441  ...                     TC         25
# 2     TS -11.9144  172.412  ...                     TC         25
# 3     TS -11.6863  172.435  ...                     TC         25
# 4     TS -11.5000  172.500  ...                     TC         25
#
#   TD9636_LAT TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 0      -12.5      172.5            1              25               6
# 1   -12.2234    172.469            1                               6
# 2   -11.9575     172.45            1                               5
# 3   -11.7128    172.456            1                               4
# 4      -11.5      172.5            1                               4
#
#   STORM_DIR_degrees
# 0               351
# 1               351
# 2               358
# 3                12
# 4                22
#
# [5 rows x 22 columns]

# %%
# Get geohash values
df['geohash']=df.apply(lambda x: gh.encode(x.LAT, x.LON, precision=5), axis=1)
df['geohash2']=df.apply(lambda x: gh.encode(x.LAT, x.LON, precision=2), axis=1)
df.head()
# Out:
#              SID  SEASON_Year  NUMBER BASIN SUBBASIN  NAME        ISO_TIME  \
# 0  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 0:00
# 1  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 3:00
# 2  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 6:00
# 3  1980001S13173         1980       1    SP       MM  PENI   1/1/1980 9:00
# 4  1980001S13173         1980       1    SP       MM  PENI  1/1/1980 12:00
#
#   NATURE      LAT      LON  ... DS824_PRES TD9636_LAT TD9636_LON TD9636_STAGE  \
# 0     TS -12.5000  172.500  ...                 -12.5      172.5            1
# 1     TS -12.1927  172.441  ...              -12.2234    172.469            1
# 2     TS -11.9144  172.412  ...              -11.9575     172.45            1
# 3     TS -11.6863  172.435  ...              -11.7128    172.456            1
# 4     TS -11.5000  172.500  ...                 -11.5      172.5            1
#
#   TD9636_WIND_KTS STORM_SPEED_KTS STORM_DIR_degrees geohash geohash3 geohash2
# 0              25               6               351   rvf8v      rvf       rv
# 1                               6               351   rvfde      rvf       rv
# 2                               5               358   rvfs5      rvf       rv
# 3                               4                12   rvfte      rvf       rv
# 4                               4                22   rvfwt      rvf       rv
#
# [5 rows x 25 columns]

# %%
#add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df, s=0.05
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);
# Out:
# C:\Users\jbate\anaconda3\envs\PythonData\lib\site-packages\contextily\tile.py:583: RuntimeWarning: divide by zero encountered in log2
#   zoom_lon = np.ceil(np.log2(360 * 2.0 / lon_length))

# %%
#Filter df to North Atlantic(NA) basin
df_NA = df.loc[df['BASIN']=='NA']
df_NA.head()
# Out:
#                 SID  SEASON_Year  NUMBER BASIN SUBBASIN   NAME  \
# 3212  1980214N11330         1980      57    NA       NA  ALLEN
# 3213  1980214N11330         1980      57    NA       NA  ALLEN
# 3214  1980214N11330         1980      57    NA       NA  ALLEN
# 3215  1980214N11330         1980      57    NA       NA  ALLEN
# 3216  1980214N11330         1980      57    NA       NA  ALLEN
#
#              ISO_TIME NATURE      LAT      LON  ... DS824_PRES TD9636_LAT  \
# 3212  7/31/1980 12:00     NR  11.0000 -30.0000  ...
# 3213  7/31/1980 15:00     NR  10.9509 -31.1101  ...
# 3214  7/31/1980 18:00     NR  10.9000 -32.2000  ...
# 3215  7/31/1980 21:00     NR  10.8496 -33.2574  ...
# 3216    8/1/1980 0:00     TS  10.8000 -34.3000  ...
#
#      TD9636_LON TD9636_STAGE TD9636_WIND_KTS STORM_SPEED_KTS  \
# 3212                                                      22
# 3213                                                      22
# 3214                                                      21
# 3215                                                      21
# 3216                                                      21
#
#      STORM_DIR_degrees geohash geohash3 geohash2
# 3212               267   e3fwt      e3f       e3
# 3213               267   e3cyk      e3c       e3
# 3214               267   e3cn5      e3c       e3
# 3215               267   e3bme      e3b       e3
# 3216               267   e1zt7      e1z       e1
#
# [5 rows x 25 columns]

# %%
#Map North Atlantic region and add basemap with scatterplot

joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_NA, s=0.05
)
contextily.add_basemap(
    joint_axes.ax_joint,
    crs="EPSG:4326",
    source=contextily.providers.CartoDB.PositronNoLabels
);

# %%
#Comment out after first run.

# #export storm data to csv
# df_NA.to_csv('NA_Storm_Data.csv',index=True)

# %%
df_NA.to_sql(schema='public', name='NA_Storms', con=engine)

# %%
#Import FL geojson
fname = "./Resources/gz_2010_us_040_00_500k.json"

df_US = gp.read_file(fname)



print(type(df_US))

df_US.head(5)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#         GEO_ID STATE           NAME LSAD  CENSUSAREA  \
# 0  0400000US23    23          Maine        30842.923
# 1  0400000US25    25  Massachusetts         7800.058
# 2  0400000US26    26       Michigan        56538.901
# 3  0400000US30    30        Montana       145545.801
# 4  0400000US32    32         Nevada       109781.180
#
#                                             geometry
# 0  MULTIPOLYGON (((-67.61976 44.51975, -67.61541 ...
# 1  MULTIPOLYGON (((-70.83204 41.60650, -70.82373 ...
# 2  MULTIPOLYGON (((-88.68443 48.11579, -88.67563 ...
# 3  POLYGON ((-104.05770 44.99743, -104.25015 44.9...
# 4  POLYGON ((-114.05060 37.00040, -114.04999 36.9...

# %%
df_FL = df_US.loc[df_US['NAME'] == 'Florida']

df_FL
# Out:
#          GEO_ID STATE     NAME LSAD  CENSUSAREA  \
# 27  0400000US12    12  Florida        53624.759
#
#                                              geometry
# 27  MULTIPOLYGON (((-85.15641 29.67963, -85.13740 ...

# %%
# REmoved due to long run time

# fname = "./Resources/gz_2010_us_040_00_500k.json"

# gdf = gp.read_file(fname)


# df_US = polygeohasher.create_geohash_list(gdf, 5,inner=False)

# %%
df_US
# Out:
#          GEO_ID STATE                  NAME LSAD  CENSUSAREA  \
# 0   0400000US23    23                 Maine        30842.923
# 1   0400000US25    25         Massachusetts         7800.058
# 2   0400000US26    26              Michigan        56538.901
# 3   0400000US30    30               Montana       145545.801
# 4   0400000US32    32                Nevada       109781.180
# 5   0400000US34    34            New Jersey         7354.220
# 6   0400000US36    36              New York        47126.399
# 7   0400000US37    37        North Carolina        48617.905
# 8   0400000US39    39                  Ohio        40860.694
# 9   0400000US42    42          Pennsylvania        44742.703
# 10  0400000US44    44          Rhode Island         1033.814
# 11  0400000US47    47             Tennessee        41234.896
# 12  0400000US48    48                 Texas       261231.711
# 13  0400000US49    49                  Utah        82169.620
# 14  0400000US53    53            Washington        66455.521
# 15  0400000US55    55             Wisconsin        54157.805
# 16  0400000US72    72           Puerto Rico         3423.775
# 17  0400000US24    24              Maryland         9707.241
# 18  0400000US01    01               Alabama        50645.326
# 19  0400000US02    02                Alaska       570640.950
# 20  0400000US04    04               Arizona       113594.084
# 21  0400000US05    05              Arkansas        52035.477
# 22  0400000US06    06            California       155779.220
# 23  0400000US08    08              Colorado       103641.888
# 24  0400000US09    09           Connecticut         4842.355
# 25  0400000US10    10              Delaware         1948.543
# 26  0400000US11    11  District of Columbia           61.048
# 27  0400000US12    12               Florida        53624.759
# 28  0400000US13    13               Georgia        57513.485
# 29  0400000US15    15                Hawaii         6422.628
# 30  0400000US16    16                 Idaho        82643.117
# 31  0400000US17    17              Illinois        55518.930
# 32  0400000US18    18               Indiana        35826.109
# 33  0400000US19    19                  Iowa        55857.130
# 34  0400000US20    20                Kansas        81758.717
# 35  0400000US21    21              Kentucky        39486.338
# 36  0400000US22    22             Louisiana        43203.905
# 37  0400000US27    27             Minnesota        79626.743
# 38  0400000US28    28           Mississippi        46923.274
# 39  0400000US29    29              Missouri        68741.522
# 40  0400000US31    31              Nebraska        76824.171
# 41  0400000US33    33         New Hampshire         8952.651
# 42  0400000US35    35            New Mexico       121298.148
# 43  0400000US38    38          North Dakota        69000.798
# 44  0400000US40    40              Oklahoma        68594.921
# 45  0400000US41    41                Oregon        95988.013
# 46  0400000US45    45        South Carolina        30060.696
# 47  0400000US46    46          South Dakota        75811.000
# 48  0400000US50    50               Vermont         9216.657
# 49  0400000US51    51              Virginia        39490.086
# 50  0400000US54    54         West Virginia        24038.210
# 51  0400000US56    56               Wyoming        97093.141
#
#                                              geometry
# 0   MULTIPOLYGON (((-67.61976 44.51975, -67.61541 ...
# 1   MULTIPOLYGON (((-70.83204 41.60650, -70.82373 ...
# 2   MULTIPOLYGON (((-88.68443 48.11579, -88.67563 ...
# 3   POLYGON ((-104.05770 44.99743, -104.25015 44.9...
# 4   POLYGON ((-114.05060 37.00040, -114.04999 36.9...
# 5   POLYGON ((-75.52684 39.65571, -75.52634 39.656...
# 6   MULTIPOLYGON (((-71.94356 41.28668, -71.92680 ...
# 7   MULTIPOLYGON (((-82.60288 36.03983, -82.60074 ...
# 8   MULTIPOLYGON (((-82.81349 41.72347, -82.81049 ...
# 9   POLYGON ((-75.41504 39.80179, -75.42804 39.809...
# 10  MULTIPOLYGON (((-71.28157 41.64821, -71.27817 ...
# 11  POLYGON ((-81.67754 36.58812, -81.68014 36.585...
# 12  MULTIPOLYGON (((-97.13436 27.89633, -97.13360 ...
# 13  POLYGON ((-114.05060 37.00040, -114.05175 37.0...
# 14  MULTIPOLYGON (((-123.09055 49.00198, -123.0353...
# 15  MULTIPOLYGON (((-90.45525 47.02400, -90.45713 ...
# 16  MULTIPOLYGON (((-65.58733 18.38199, -65.59122 ...
# 17  MULTIPOLYGON (((-76.07147 38.20350, -76.04879 ...
# 18  MULTIPOLYGON (((-85.00237 31.00068, -85.02411 ...
# 19  MULTIPOLYGON (((-164.97620 54.13459, -164.9377...
# 20  POLYGON ((-109.04522 36.99908, -109.04524 36.9...
# 21  POLYGON ((-94.55929 36.49950, -94.51948 36.499...
# 22  MULTIPOLYGON (((-122.44632 37.86105, -122.4385...
# 23  POLYGON ((-102.04224 36.99308, -102.05450 36.9...
# 24  MULTIPOLYGON (((-71.85957 41.32240, -71.86823 ...
# 25  MULTIPOLYGON (((-75.55945 39.62981, -75.55910 ...
# 26  POLYGON ((-77.03860 38.79151, -77.03890 38.800...
# 27  MULTIPOLYGON (((-85.15641 29.67963, -85.13740 ...
# 28  POLYGON ((-81.44412 30.70971, -81.44872 30.709...
# 29  MULTIPOLYGON (((-171.73761 25.79210, -171.7223...
# 30  POLYGON ((-111.04669 42.00157, -111.41587 42.0...
# 31  POLYGON ((-87.53233 39.99778, -87.53254 39.987...
# 32  POLYGON ((-88.02803 37.79922, -88.02938 37.803...
# 33  POLYGON ((-95.76565 40.58521, -95.75889 40.588...
# 34  POLYGON ((-94.61808 36.99813, -94.62522 36.998...
# 35  MULTIPOLYGON (((-83.67541 36.60081, -83.67561 ...
# 36  MULTIPOLYGON (((-88.86507 29.75271, -88.88975 ...
# 37  POLYGON ((-91.37161 43.50095, -91.37695 43.500...
# 38  MULTIPOLYGON (((-88.71072 30.25080, -88.65680 ...
# 39  POLYGON ((-89.53910 36.49820, -89.53452 36.491...
# 40  POLYGON ((-95.76565 40.58521, -95.76853 40.583...
# 41  MULTIPOLYGON (((-72.45852 42.72685, -72.45849 ...
# 42  POLYGON ((-109.05004 31.33250, -109.05017 31.4...
# 43  POLYGON ((-96.56328 45.93524, -96.57690 45.935...
# 44  POLYGON ((-94.61792 36.49941, -94.61531 36.484...
# 45  POLYGON ((-117.22007 44.30138, -117.22245 44.2...
# 46  POLYGON ((-78.54109 33.85111, -78.55394 33.847...
# 47  POLYGON ((-96.44341 42.48949, -96.45971 42.486...
# 48  POLYGON ((-72.04008 44.15575, -72.04271 44.152...
# 49  MULTIPOLYGON (((-76.04653 37.95359, -76.04169 ...
# 50  POLYGON ((-81.96830 37.53780, -81.96540 37.541...
# 51  POLYGON ((-109.05008 41.00066, -109.17368 41.0...

# %%
# df_FL = df_US.loc[df_US['NAME'] == 'Florida']

# df_FL

# %%
df_FL.dtypes
# Out:
# GEO_ID          object
# STATE           object
# NAME            object
# LSAD            object
# CENSUSAREA     float64
# geometry      geometry
# dtype: object

# %%
df_FL['geometry'].head()
# Out:
# 27    MULTIPOLYGON (((-85.15641 29.67963, -85.13740 ...
# Name: geometry, dtype: geometry

# %%
ax = df_FL.plot(
color='aquamarine', edgecolor='slategrey')
#gp.plot(ax=ax)

# %%
#export geojson to csv
df_FL.to_csv('df_FL_out.csv', columns=['geometry'],index=False)

# %%
df_FL = pd.read_csv(Path('./Resources/FL_LAT_LON.csv'))
df_FL.head()
# Out:
#    ID        LON        LAT
# 0   1 -85.156415  29.679628
# 1   2 -85.137397  29.684348
# 2   3 -85.134639  29.686569
# 3   4 -85.114268  29.688658
# 4   5 -85.093902  29.684838

# %%
#Map target area 
joint_axes = sb.jointplot(
    x='LON', y='LAT', data=df_FL, s=1
)

# %%
#Get Geohash data for FL boundaries

df_FL['geohash']=df_FL.apply(lambda x: gh.encode(x.LAT, x.LON, precision=5), axis=1)
df_FL
# Out:
#         ID        LON        LAT geohash
# 0        1 -85.156415  29.679628   dj72y
# 1        2 -85.137397  29.684348   dj72y
# 2        3 -85.134639  29.686569   dj72y
# 3        4 -85.114268  29.688658   dj72z
# 4        5 -85.093902  29.684838   dj72z
# ...    ...        ...        ...     ...
# 2223  2224 -84.573975  29.830572   dj7ce
# 2224  2225 -84.570877  29.822495   dj7ce
# 2225  2226 -84.579987  29.806856   dj7ce
# 2226  2227 -84.624840  29.788467   dj7c6
# 2227  2228 -84.670555  29.777298   dj7c3
#
# [2228 rows x 4 columns]

# %%
# #export df_FL to csv
df_FL.to_csv('FL_data.csv', mode='w')

# %%
 #Export df_FL to Postgres
df_FL.to_sql(name='target', con=engine)

# %%
df_fl_storms = pd.read_sql_table("fl_storms", engine)
df_fl_storms
# Out:
#      NUMBER    NAME  SEASON_Year NATURE      LAT      LON WMO_WIND_KTS  \
# 0        34     ANA         1991     DS  28.0000 -82.7000           20
# 1        34     ANA         1991     DS  28.0000 -82.7000           20
# 2        34     ANA         1991     DS  27.6425 -82.7375
# 3        34     ANA         1991     DS  27.6425 -82.7375
# 4        34     ANA         1991     DS  27.6425 -82.7375
# ..      ...     ...          ...    ...      ...      ...          ...
# 209      62  DENNIS         1981     TS  24.7300 -81.2999
# 210      62  DENNIS         1981     TS  24.7300 -81.2999
# 211      62  DENNIS         1981     TS  24.7300 -81.2999
# 212      62  DENNIS         1981     TS  24.7300 -81.2999
# 213      62  DENNIS         1981     TS  24.7300 -81.2999
#
#     WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees geohash
# 0       1012               7                 9   dhvpq
# 1       1012               7                 9   dhvpq
# 2                          7                 0   dhvjm
# 3                          7                 0   dhvjm
# 4                          7                 0   dhvjm
# ..       ...             ...               ...     ...
# 209                        4                 0   dhqht
# 210                        4                 0   dhqht
# 211                        4                 0   dhqht
# 212                        4                 0   dhqht
# 213                        4                 0   dhqht
#
# [214 rows x 11 columns]

# %%
df_na_storms_summary = pd.read_sql_table("na_storms_summary", engine)
df_na_storms_summary
# Out:
#      NUMBER     NAME  SEASON_Year          ISO_TIME NATURE   LAT      LON  \
# 0        20  ALBERTO         2012    5/19/2012 0:00     DS  33.1 -77.0000
# 1         2     ALEX         2016    1/10/2016 0:00     ET  34.4 -54.2000
# 2        47   ALICIA         1983   8/15/1983 12:00     TS  27.3 -90.5000
# 3        57    ALLEN         1980   7/31/1980 12:00     NR  11.0 -30.0000
# 4        27  ALLISON         1995    6/10/1995 0:00     ET  57.0 -52.0000
# ..      ...      ...          ...               ...    ...   ...      ...
# 170      72    VICKY         2020   9/14/2020 18:00     TS  19.0 -29.1667
# 171      93    VINCE         2005   10/10/2005 0:00     TS  34.3 -18.3000
# 172      74  WILFRED         2020   9/14/2020 18:00     NR   8.7 -17.4000
# 173      97    WILMA         2005  10/22/2005 12:00     TS  21.0 -87.1000
# 174     115     ZETA         2005     1/1/2006 0:00     TS  25.6 -38.3000
#
#     WMO_WIND_KTS WMO_PRES STORM_SPEED_KTS STORM_DIR_degrees geohash geohash3  \
# 0             25     1010               3               196   dmchr      dmc
# 1             65      981              16               119   dy17w      dy1
# 2             30     1009               5               258   9uzek      9uz
# 3             25                       22               267   e3fwt      e3f
# 4             40      997              36               360   ff5h2      ff5
# ..           ...      ...             ...               ...     ...      ...
# 170                                     8               299   e77k0      e77
# 171           60      990               7                74   ew4gp      ew4
# 172                                     8               277   e9e9k      e9e
# 173          100      947               3               351   d5dp3      d5d
# 174           50      997               2               221   ehsc8      ehs
#
#     Strike_Target
# 0               1
# 1               0
# 2               0
# 3               0
# 4               1
# ..            ...
# 170             0
# 171             0
# 172             0
# 173             1
# 174             0
#
# [175 rows x 14 columns]

# %%
# #export df_na_storms_summary to csv
df_na_storms_summary.to_csv('na_storms_summary.csv', mode='w')
